# %% [markdown]
# <a href="https://colab.research.google.com/github/triukhan/computer-vision-lessons/blob/main/Homework_(5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HOMEWORK 9
#
# In this homework, you are going to use the dlib face detector and apply it to an image of your liking. You can follow the procedure shown in lesson 9. Please always comment your code so I can see what you're doing :-)
#
# For this homework we are not going to provide you with any code, you'll have to build the face detector on your own.

# %% [markdown]
# ### Step 0
#
# Run the necessary imports.

# %%
import cv2
import math
import numpy as np
import dlib
from matplotlib import pyplot as plt
from google.colab import drive
plt.rcParams['figure.figsize'] = [15, 10]
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Step 1
#
# Load an image (any image that contains faces).

# %%
img_first = cv2.imread('/content/drive/MyDrive/first.webp')
img_sec = cv2.imread('/content/drive/MyDrive/second.jpg')
img_thrd = cv2.imread('/content/drive/MyDrive/third.jpg')
img_frth = cv2.imread('/content/drive/MyDrive/forth.webp')
img_fifth = cv2.imread('/content/drive/MyDrive/fifth.webp')
img_sixth = cv2.imread('/content/drive/MyDrive/sixth.jpg')

# %% [markdown]
# ### Step 2
#
# Load the dlib face predictor.

# %%
detector = dlib.get_frontal_face_detector()

# %% [markdown]
# ### Step 3
#
# Run the predictor on your image.

# %%
def detect_face_dlib(img):
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

  rects = detector(gray, 2)

  def rect_to_bb(rect):
    x = rect.left()
    y = rect.top()
    w = rect.right() - x
    h = rect.bottom() - y
    return (x, y, w, h)

  result = img.copy()
  for rect in rects:
    x, y, w, h = rect_to_bb(rect)
    cv2.rectangle(result, (x, y), (x + w, y + h), (0, 255, 0), 3)
  plt.imshow(result)

# %% [markdown]
# ### Step 4
#
# Draw bounding boxes around the detected faces and plot the image. Use different colour for each face.

# %%
detect_face_dlib(img_first)

# %% [markdown]
# ### Step 5 (optional)
#
# Repeat the process with a different and more challenging image (more faces, smaller faces, people with glasses, hats, helmets, etc.). How does the detector perform? Is it robust?

# %%
detect_face_dlib(img_sec)

# %%
detect_face_dlib(img_thrd)

# %%
detect_face_dlib(img_frth)

# %%
detect_face_dlib(img_fifth)

# %%
detect_face_dlib(img_sixth)

# %% [markdown]
# In my opinion face detection require high accurancy, so the model is not good and not bad. In the most situations it doesnt have false detections (except fifth image), but can skip true detection. Raw dlib face detector is not suitable for most problems.
