# %% [markdown]
# <a href="https://colab.research.google.com/github/triukhan/computer-vision-lessons/blob/main/Homework_(7)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HOMEWORK 14
#
# In this homework we will be working with the Fashion MNIST dataset. You will be given a classifier which suffers from considerable overfitting. Your objective will be to employ regularization techniques to mitigate the overfitting problem.
#
# Let's start with the usual imports.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Dataset
#
# The MNIST fashgion dataset [link](https://github.com/zalandoresearch/fashion-mnist) was build by Zalando Reasearch tem consists of monochrome images of different type of clothing, namely:
# * 0	T-shirt/top
# * 1	Trouser
# * 2	Pullover
# * 3	Dress
# * 4	Coat
# * 5	Sandal
# * 6	Shirt
# * 7	Sneaker
# * 8	Bag
# * 9	Ankle boot
#
# It is also one of the Keras built-in datasets. Let's load the images and quickly inspect it.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %% [markdown]
# Let's visualise some random samples.

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Building the Classifier
#
# We are now going to build the baseline classifier that you will use throughout this homework.

# %%
# Data normalization
x_train = x_train/255
x_test = x_test/255

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 74ms/step - accuracy: 0.8621 - loss: 0.3919 - val_accuracy: 0.8833 - val_loss: 0.3248
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 71ms/step - accuracy: 0.9058 - loss: 0.2618 - val_accuracy: 0.8919 - val_loss: 0.3026
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9209 - loss: 0.2196 - val_accuracy: 0.8922 - val_loss: 0.3072
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.9330 - loss: 0.1884 - val_accuracy: 0.8933 - val_loss: 0.3214
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9416 - loss: 0.1655 - val_accuracy: 0.8936 - val_loss: 0.3401
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9490 - loss: 0.1444 - val_accuracy: 0.8940 - val_loss: 0.3619
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 73ms/step - accuracy: 0.9556 - loss: 0.1265 - val_accuracy: 0.8930 - val_loss: 0.3989
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 74ms/step - accuracy: 0.9600 - loss: 0.1138 - val_accuracy: 0.8906 - val_loss: 0.4330
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 71ms/step - accuracy: 0.9638 - loss: 0.1034 - val_accuracy: 0.8913 - val_loss: 0.4606
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 71ms/step - accuracy: 0.9671 - loss: 0.0922 - val_accuracy: 0.8884 - val_loss: 0.5029
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 71ms/step - accuracy: 0.9704 - loss: 0.0827 - val_accuracy: 0.8859 - val_loss: 0.5395
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 71ms/step - accuracy: 0.9731 - loss: 0.0757 - val_accuracy: 0.8835 - val_loss: 0.5893
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9731 - loss: 0.0748 - val_accuracy: 0.8811 - val_loss: 0.6121
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9763 - loss: 0.0674 - val_accuracy: 0.8790 - val_loss: 0.6832
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 71ms/step - accuracy: 0.9770 - loss: 0.0631 - val_accuracy: 0.8711 - val_loss: 0.7377
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 78s 83ms/step - accuracy: 0.9783 - loss: 0.0589 - val_accuracy: 0.8778 - val_loss: 0.7261
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.9798 - loss: 0.0566 - val_accuracy: 0.8745 - val_loss: 0.7583
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 75s 79ms/step - accuracy: 0.9804 - loss: 0.0530 - val_accuracy: 0.8779 - val_loss: 0.7687
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9817 - loss: 0.0496 - val_accuracy: 0.8798 - val_loss: 0.8059
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.9817 - loss: 0.0492 - val_accuracy: 0.8859 - val_loss: 0.7684
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 97s 89ms/step - accuracy: 0.9833 - loss: 0.0455 - val_accuracy: 0.8840 - val_loss: 0.7878
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 128s 74ms/step - accuracy: 0.9845 - loss: 0.0414 - val_accuracy: 0.8854 - val_loss: 0.8097
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 73ms/step - accuracy: 0.9850 - loss: 0.0404 - val_accuracy: 0.8781 - val_loss: 0.8734
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 72ms/step - accuracy: 0.9865 - loss: 0.0366 - val_accuracy: 0.8836 - val_loss: 0.8971
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9855 - loss: 0.0394 - val_accuracy: 0.8766 - val_loss: 0.9584
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 69s 73ms/step - accuracy: 0.9863 - loss: 0.0367 - val_accuracy: 0.8733 - val_loss: 0.9855
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9875 - loss: 0.0338 - val_accuracy: 0.8717 - val_loss: 1.0039
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 71ms/step - accuracy: 0.9881 - loss: 0.0326 - val_accuracy: 0.8760 - val_loss: 0.9975
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 72ms/step - accuracy: 0.9870 - loss: 0.0344 - val_accuracy: 0.8805 - val_loss: 1.0234
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 72ms/step - accuracy: 0.9889 - loss: 0.0310 - val_accuracy: 0.8707 - val_loss: 1.0806
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 69s 73ms/step - accuracy: 0.9895 - loss: 0.0293 - val_accuracy: 0.8626 - val_loss: 1.1811
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 71ms/step - accuracy: 0.9887 - loss: 0.0312 - val_accuracy: 0.8765 - val_loss: 1.0879
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 71ms/step - accuracy: 0.9897 - loss: 0.0273 - val_accuracy: 0.8792 - val_loss: 1.1398
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9917 - loss: 0.0232 - val_accuracy: 0.8771 - val_loss: 1.1598
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 69s 74ms/step - accuracy: 0.9895 - loss: 0.0289 - val_accuracy: 0.8743 - val_loss: 1.1853
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 75ms/step - accuracy: 0.9908 - loss: 0.0250 - val_accuracy: 0.8725 - val_loss: 1.2371
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9908 - loss: 0.0258 - val_accuracy: 0.8696 - val_loss: 1.2239
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9907 - loss: 0.0255 - val_accuracy: 0.8740 - val_loss: 1.1998
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9913 - loss: 0.0234 - val_accuracy: 0.8801 - val_loss: 1.2044
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9923 - loss: 0.0224 - val_accuracy: 0.8750 - val_loss: 1.2647
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 72ms/step - accuracy: 0.9911 - loss: 0.0244 - val_accuracy: 0.8731 - val_loss: 1.3095
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9921 - loss: 0.0228 - val_accuracy: 0.8773 - val_loss: 1.2454
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 69s 73ms/step - accuracy: 0.9911 - loss: 0.0260 - val_accuracy: 0.8820 - val_loss: 1.1492
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 71ms/step - accuracy: 0.9936 - loss: 0.0186 - val_accuracy: 0.8827 - val_loss: 1.1553
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 71ms/step - accuracy: 0.9927 - loss: 0.0201 - val_accuracy: 0.8825 - val_loss: 1.2281
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9938 - loss: 0.0176 - val_accuracy: 0.8814 - val_loss: 1.2878
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9917 - loss: 0.0236 - val_accuracy: 0.8811 - val_loss: 1.2643
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 72ms/step - accuracy: 0.9925 - loss: 0.0222 - val_accuracy: 0.8831 - val_loss: 1.3094
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 71ms/step - accuracy: 0.9931 - loss: 0.0189 - val_accuracy: 0.8784 - val_loss: 1.3288
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9936 - loss: 0.0185 - val_accuracy: 0.8815 - val_loss: 1.2592

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])

plot_history(history)
# Out:
# Train Acc      0.9935666918754578
# Validation Acc 0.8815000057220459

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %%
# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust

from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras import regularizers

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = BatchNormalization()(net)
net = Activation('relu')(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.2)(net)
net = Flatten()(net)
net = Dense(128)(net)
net = BatchNormalization()(net)
net = Activation('relu')(net)
net = Dropout(0.5)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │       802,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 805,194 (3.07 MB)
#  Trainable params: 804,874 (3.07 MB)
#  Non-trainable params: 320 (1.25 KB)

# %%
# Train the network
from sklearn.utils import shuffle
from tensorflow.keras.callbacks import EarlyStopping

def datagen(x, y, batch_size):
    num_samples = len(y)
    while True:
        for idx in range(0, num_samples, batch_size):
            x_ = x[idx:idx + batch_size, ...]
            y_ = y[idx:idx + batch_size]

            if len(y_) < batch_size:
                x, y = shuffle(x, y)
                break

            for idx_aug in range(batch_size):
                if np.random.rand() > 0.5:
                    x_[idx_aug, ...] = np.fliplr(x_[idx_aug, ...])

            yield x_, y_

early_stop = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=5,
    restore_best_weights=True
)

epochs = 50
batch_size = 64
steps_per_epoch = len(y_train) // batch_size
generator = datagen(x_train, y_train, batch_size)
print(x_train.shape)

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(generator, steps_per_epoch=steps_per_epoch, epochs=epochs, validation_data=(x_test, y_test), callbacks=[early_stop])
# Out:
# (60000, 28, 28)
# Epoch 1/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 76s 79ms/step - accuracy: 0.9199 - loss: 0.2155 - val_accuracy: 0.9136 - val_loss: 0.2449
# Epoch 2/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 74s 78ms/step - accuracy: 0.9215 - loss: 0.2143 - val_accuracy: 0.9139 - val_loss: 0.2419
# Epoch 3/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 77s 82ms/step - accuracy: 0.9240 - loss: 0.2056 - val_accuracy: 0.9179 - val_loss: 0.2378
# Epoch 4/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.9257 - loss: 0.2018 - val_accuracy: 0.9176 - val_loss: 0.2365
# Epoch 5/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 74s 79ms/step - accuracy: 0.9266 - loss: 0.1994 - val_accuracy: 0.9122 - val_loss: 0.2456
# Epoch 6/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9272 - loss: 0.1951 - val_accuracy: 0.9189 - val_loss: 0.2308
# Epoch 7/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 74s 79ms/step - accuracy: 0.9292 - loss: 0.1906 - val_accuracy: 0.9127 - val_loss: 0.2473
# Epoch 8/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 74s 79ms/step - accuracy: 0.9308 - loss: 0.1854 - val_accuracy: 0.9196 - val_loss: 0.2373
# Epoch 9/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 72s 76ms/step - accuracy: 0.9323 - loss: 0.1814 - val_accuracy: 0.9185 - val_loss: 0.2377
# Epoch 10/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9336 - loss: 0.1814 - val_accuracy: 0.9220 - val_loss: 0.2270
# Epoch 11/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.9342 - loss: 0.1762 - val_accuracy: 0.9224 - val_loss: 0.2267
# Epoch 12/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 74s 79ms/step - accuracy: 0.9348 - loss: 0.1760 - val_accuracy: 0.9242 - val_loss: 0.2267
# Epoch 13/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 75s 80ms/step - accuracy: 0.9361 - loss: 0.1707 - val_accuracy: 0.9188 - val_loss: 0.2407
# Epoch 14/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 74s 79ms/step - accuracy: 0.9372 - loss: 0.1692 - val_accuracy: 0.9179 - val_loss: 0.2445
# Epoch 15/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.9380 - loss: 0.1652 - val_accuracy: 0.9191 - val_loss: 0.2425
# Epoch 16/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 74s 79ms/step - accuracy: 0.9382 - loss: 0.1642 - val_accuracy: 0.9229 - val_loss: 0.2362
# Epoch 17/50
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.9385 - loss: 0.1633 - val_accuracy: 0.9231 - val_loss: 0.2357

# %%
# Show the results
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])

plot_history(history)
# Out:
# Train Acc      0.9385172128677368
# Validation Acc 0.9230999946594238

# %% [markdown]
# ### Questions
#
# * What have you done in order to improve the performance? Firstly, dropout, then batch normalization, and data augmentation it was first iteration; the result was about 92%, train accuracy decreased to 96%, as I understood it's ok. Then I added MaxPooling2D(pool_size=(2, 2))(net), and (thank god, my CPU appreciated this) it wasn't decreased much. Also, I added EarlyStopping to track val_accuracy. Then I had experiments with regularizers.l2 as a parameter to conv2d and dense with different lambda (0.001 and 0.0005), also tried putting it only on the single dense layer - in all the cases result was worse for train_acc as for val_acc, as I google mb it's because my model is too small. In the end, I decreased the number of neurons in the first Dense layer (128 -> 64) and results become a little worse. And in the end I tried without Data augmentation (val_acc became lower) and without BatchNormalization (val_acc and train acc became lower). Also the correctly (as chatgpt said) would be remove activation="relu" from conv2d layer, because of Activation layer after batch normalization, but in practice with it results slightly better; mb it happens (as chatgpt said) because of model is small.
# * Have you tried configurations that did not work out? Weight regularization didn't help; the other options gave some impact.
